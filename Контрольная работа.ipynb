# %% [markdown]
# ## Контрольная работа

# %%
import sympy as sp
from scipy.integrate import odeint 
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from ODEplot import *

colors = ['#1f77b4', '#ff7f0e', '#2ca02c', '#d62728',
          '#9467bd', '#8c564b', '#e377c2', '#7f7f7f',
          '#bcbd22', '#17becf']
sns.set(style='whitegrid', context='notebook', palette=tuple(colors), 
        rc={'axes.labelsize': 16})

# %matplotlib inline
# %config InlineBackend.figure_formats = {'png', 'retina'}
sp.init_printing()

# %%
def func(phiv,t):
    phi, v = phiv
    return [v, 0.2*v*(1-v**2)-np.sin(phi)+np.sin(np.pi/8)]

# %%
init_cond = np.array([1, 2])
t = np.linspace(0,30,200)
x,y = odeint(func, init_cond, t)[0][1], odeint(func, init_cond, t)[1][1]

# %%
xvalues, yvalues = np.meshgrid(np.arange(-8, 8, 0.1), np.arange(-3, 3, 0.1))
psidot = yvalues
vdot = 0.2*yvalues*(1-yvalues**2)-np.sin(xvalues)+np.sin(np.pi/8)
plt.streamplot(xvalues, yvalues, psidot, vdot, color=psidot, linewidth=2, cmap='winter')
plt.grid(); plt.show()

# %%
x = np.linspace(0,8,300)
y = 4*(-0.1+0.3*(x/(1+x)))*(1-x/8)
plt.plot(x,y)

# %%
x = 6
y = 0.1
-0.2*y+0.05*x*y
# Out:
# 0.010000000000000002

# %%
x = 2
y = 0.1
(-0.1*x+0.3*x**2/(1+x))*(1-x/8)-0.25*x*y
# Out:
# 0.09999999999999996

# %%
xvalues, yvalues = np.meshgrid(np.arange(0, 10, 0.1), np.arange(0, 2, 0.1))
xdot = 0.3*xvalues - 0.1*xvalues**2 - 0.2*xvalues*yvalues
ydot = -0.5*yvalues+0.25*xvalues*yvalues
plt.streamplot(xvalues, yvalues, xdot, ydot, color=xdot, linewidth=2, cmap='winter')
plt.grid(); plt.show()

# %%
xvalues, yvalues = np.meshgrid(np.arange(0, 11, 0.1), np.arange(0, 2, 0.1))
xdot = 0.4*xvalues - 0.05*xvalues**2 - 0.4*xvalues*yvalues
ydot = -0.2*yvalues+0.02*xvalues*yvalues
plt.streamplot(xvalues, yvalues, xdot, ydot, color=xdot, linewidth=2, cmap='winter')
plt.grid(); plt.show()

# %%
xvalues, yvalues = np.meshgrid(np.arange(-1, 8, 0.1), np.arange(-0.5, 1, 0.1))
xdot = (-0.1*xvalues + 0.3*xvalues**2/(1+xvalues))*(1-xvalues/8) - 0.25*xvalues*yvalues
ydot = -0.2*yvalues+0.05*xvalues*yvalues
plt.streamplot(xvalues, yvalues, xdot, ydot, color=xdot, linewidth=2, cmap='winter')
plt.grid(); plt.show()
# Out:
# /home/snopoff/.local/lib/python3.7/site-packages/ipykernel_launcher.py:2: RuntimeWarning: divide by zero encountered in true_divide
